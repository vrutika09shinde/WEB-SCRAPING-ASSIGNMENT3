# %% [markdown]
# # ANS = 1 & 2

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

from selenium import webdriver

from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException

import requests

from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.amazon.in/')

# %%
item_bar = driver.find_element(By.XPATH,'//input[@class="nav-input nav-progressive-attribute"]')
item_bar.send_keys("guitar")

# %%
search = driver.find_element(By.XPATH,'//span[@class="nav-search-submit-text nav-sprite nav-progressive-attribute"]')
search.click()

# %%
Brand_name = []

start = 0
end   = 3

for page in range(start,end):
    brand = driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
    for i in brand:
        Brand_name.append(i.text)

next_button = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
next_button.click()
time.sleep(3)
print(Brand_name)
# Out:
# ['Henrix 38C PRO 38 Inch Cutaway Acoustic Guitar With with Die-cast Tuners, Dual-action Truss Rod, Gig-Bag, Picks, String set, String Winder, Strap & Polishing Cloth - Natural', 'Kadence AstroMan Electric Guitar, 21 FRETS, ROSEWOOD FRETBOARD, H - S - S PICK UPS Black combo with Bag and guitar cable', '4-String Kids Guitar , Musical Instrument for Boys & Girls ,Learning Toy Guitar for Kids (17 Inches) Pack of 1', 'YAMAHA FX280 Natural Electro Acoustic Guitar', 'Vault EA20 Guitar Kit with Learn to Play Ebook, Bag, Strings, Straps, Picks, String winder & Polishing Cloth - 40 inch Cutaway Acoustic Guitar - Natural', 'Kadence A281 Professional Acoustic Rosewood guitar (Natural, Beige)', 'Yamaha FS80C Acoustic Guitar Cutaway Concert Body With Mexa Sponge Bag, Guitar Belt, Guitar Stand, String Set & Plectrums.(NT)', 'BLUEBERRY, B-38C Acoustic Guitar Kit with Bag, Strap, One Pack Strings And 2 Picks - 38 Inch (Retro Brown)', 'BLUEBERRY VIP-382, Acoustic Guitar, Cutway Innovative design With 
# ...

# %%
print(len(Brand_name))
# Out:
# 147

# %%
Brand_price = []

start = 0
end   = 3

for page in range(start,end):
    prices = driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
    for i in prices:
        Brand_price.append(i.text)

next_button = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
next_button.click()
time.sleep(3)
print(Brand_price)
# Out:
# ['1,999', '2,447', '3,749', '8,399', '432', '11,199', '6,999', '2,395', '9,530', '4,949', '2,495', '2,399', '749', '1,770', '9,590', '4,997', '3,399', '3,809', '5,999', '4,199', '36,000', '15,499', '5,499', '14,989', '2,395', '3,304', '23,999', '21,490', '22,335', '3,290', '4,399', '4,170', '8,950', '4,170', '15,386', '4,454', '17,999', '4,999', '4,999', '2,395', '2,239', '7,499', '5,999', '2,299', '91', '735', '18,999', '2,395', '8,499', '9,799', '999', '1,999', '2,447', '3,749', '8,399', '432', '11,199', '6,999', '2,395', '9,530', '4,949', '2,495', '2,399', '749', '1,770', '9,590', '4,997', '3,399', '3,809', '5,999', '4,199', '36,000', '15,499', '5,499', '14,989', '2,395', '3,304', '23,999', '21,490', '22,335', '3,290', '4,399', '4,170', '8,950', '4,170', '15,386', '4,454', '17,999', '4,999', '4,999', '2,395', '2,239', '7,499', '5,999', '2,299', '91', '735', '18,999', '2,395', '8,499', '9,799', '999', '1,999', '2,447', '3,749', '8,399', '432', '11,199', '6,999', '2,395', '9,530', '
# ...

# %%
print(len(Brand_price))
# Out:
# 153

# %%
product_url = []

start = 0
end   = 3

for page in range(start,end):
    products = driver.find_elements(By.XPATH,'//img[@class="s-image"]')
    for i in products:
        product_url.append(i.get_attribute('src'))

next_button = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[1]/div/span[1]/div[1]/div[56]/div/div/span/a[4]')
next_button.click()
time.sleep(3)
print(product_url)
# Out:
# ['https://m.media-amazon.com/images/I/61eJNrkgvOL._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/51b00PiWCRL._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/51OR2G7O5eL._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/81yLUQp3BsL._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/71VVV-0A+YL._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/61D6o8fourL._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/51WD+W0UYEL._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/61tFRPOzsPL._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/61CM+cH51LL._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/51F8CzLvL2L._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/61ckScMih0L._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/61G01ui45RL._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/61xmf6wjKGL._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/61dpZn8+qtL._AC_UL320_.jpg', 'https://m.media-amazon.com/images/I/51IWNLQnxHL._AC_UL320_.jpg', 'https:
# ...

# %%
print(len(product_url))
# Out:
# 153

# %%
#Expected_delivery = []

#start = 0
#end   = 3

#for page in range(start,end):
 #   exp_delivery = driver.find_elements(By.XPATH,'//div[@class="a-row s-align-children-center"]/span/span')
  #  for i in products:
   #     Expected_delivery.append(i.get_attribute('span'))

#next_button = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[1]/div/span[1]/div[1]/div[56]/div/div/span/a[4]')
#next_button.click()
#time.sleep(3)
#print(Expected_delivery)

# %%
availabilty = []

start = 0
end   = 15

for page in range(start,end):
    products = driver.find_elements(By.XPATH,'//div[@class="a-row a-size-base a-color-secondary puis-interactive-asin-expander-hide"]')
    for i in products:
        availabilty.append(i.text)

next_button = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[1]/div/span[1]/div[1]/div[56]/div/div/span/a[4]')
next_button.click()
time.sleep(3)
print(availabilty)
# Out:
# ['Only 1 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 1 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 1 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 1 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 1 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.', 'Only 1 left in stock.', 'Only 2 left in stock.
# ...

# %%
print(len(availabilty))
# Out:
# 135

# %%
import pandas as pd

# %%
DF = pd.DataFrame({'Brand_name':Brand_name})

DF= DF.drop(DF.index[[135,136,137,138,139,140,141,142,143,144,145,146]],axis= 0 )
DF
# Out:
#                                             Brand_name
# 0    Henrix 38C PRO 38 Inch Cutaway Acoustic Guitar...
# 1    Kadence AstroMan Electric Guitar, 21 FRETS, RO...
# 2    4-String Kids Guitar , Musical Instrument for ...
# 3         YAMAHA FX280 Natural Electro Acoustic Guitar
# 4    Vault EA20 Guitar Kit with Learn to Play Ebook...
# ..                                                 ...
# 130  Tanglewood Roadster II TWR2 TE Semi Acoustic G...
# 131  Kadence Acoustica A01 34" Spruce Wood Acoustic...
# 132  Kadence Acoustica 40" Acoustic Solid Top Guita...
# 133  Vault EA20 Left Handed Acoustic Guitar with Le...
# 134  BLUEBERRY B-40EQ-GL, Electro Acoustic Electric...
#
# [135 rows x 1 columns]

# %%
DF = pd.DataFrame({'product_url':product_url})

DF= DF.drop(DF.index[[135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152]],axis= 0 )
DF
# Out:
#                                            product_url
# 0    https://m.media-amazon.com/images/I/61eJNrkgvO...
# 1    https://m.media-amazon.com/images/I/51b00PiWCR...
# 2    https://m.media-amazon.com/images/I/51OR2G7O5e...
# 3    https://m.media-amazon.com/images/I/81yLUQp3Bs...
# 4    https://m.media-amazon.com/images/I/71VVV-0A+Y...
# ..                                                 ...
# 130  https://m.media-amazon.com/images/I/7108nMyOSL...
# 131  https://m.media-amazon.com/images/I/71nzdkpUcW...
# 132  https://m.media-amazon.com/images/I/51RdNjn7Ar...
# 133  https://m.media-amazon.com/images/I/613FxmL6+l...
# 134  https://m.media-amazon.com/images/I/5186AmMPJs...
#
# [135 rows x 1 columns]

# %%
DF = pd.DataFrame({'Brand_price':Brand_price})

DF= DF.drop(DF.index[[135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152]],axis= 0 )
DF
# Out:
#     Brand_price
# 0         1,999
# 1         2,447
# 2         3,749
# 3         8,399
# 4           432
# ..          ...
# 130      22,335
# 131       3,290
# 132       4,399
# 133       4,170
# 134       8,950
#
# [135 rows x 1 columns]

# %%
 Df = pd.DataFrame({'availabilty':availabilty})

 Df
# Out:
#                availabilty
# 0    Only 1 left in stock.
# 1    Only 2 left in stock.
# 2    Only 1 left in stock.
# 3    Only 2 left in stock.
# 4    Only 1 left in stock.
# ..                     ...
# 130  Only 1 left in stock.
# 131  Only 1 left in stock.
# 132  Only 1 left in stock.
# 133  Only 2 left in stock.
# 134  Only 2 left in stock.
#
# [135 rows x 1 columns]

# %%
df= ({'Brand_name':Brand_name,'Brand_price':Brand_price,'availabilty':availabilty,'product_url':product_url})

df
# Out:
# {'Brand_name': ['Henrix 38C PRO 38 Inch Cutaway Acoustic Guitar With with Die-cast Tuners, Dual-action Truss Rod, Gig-Bag, Picks, String set, String Winder, Strap & Polishing Cloth - Natural',
#   'Kadence AstroMan Electric Guitar, 21 FRETS, ROSEWOOD FRETBOARD, H - S - S PICK UPS Black combo with Bag and guitar cable',
#   '4-String Kids Guitar , Musical Instrument for Boys & Girls ,Learning Toy Guitar for Kids (17 Inches) Pack of 1',
#   'YAMAHA FX280 Natural Electro Acoustic Guitar',
#   'Vault EA20 Guitar Kit with Learn to Play Ebook, Bag, Strings, Straps, Picks, String winder & Polishing Cloth - 40 inch Cutaway Acoustic Guitar - Natural',
#   'Kadence A281 Professional Acoustic Rosewood guitar (Natural, Beige)',
#   'Yamaha FS80C Acoustic Guitar Cutaway Concert Body With Mexa Sponge Bag, Guitar Belt, Guitar Stand, String Set & Plectrums.(NT)',
#   'BLUEBERRY, B-38C Acoustic Guitar Kit with Bag, Strap, One Pack Strings And 2 Picks - 38 Inch (Retro Brown)',
# ...

# %% [markdown]
# # ANS =8

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.youtube.com/')

# %%
program =driver.find_element(By.XPATH,'//input[@class="ytd-searchbox"]')
program.send_keys("cricket")

# %%
search = driver.find_element(By.XPATH,'//button[@class="style-scope ytd-searchbox"]')
search.click()

# %%
video_title =driver.find_element(By.XPATH,'//h1[@class="style-scope ytd-watch-metadata"]')
video_title.text
# Out:
# '2nd T20I | Highlights | Australia Tour Of England | 13th September 2024'

# %%
video_comments =[]
start=0
end=5

for page in range(start,end):
    url = driver.find_elements(By.XPATH,'//span[@class="yt-core-attributed-string yt-core-attributed-string--white-space-pre-wrap"]')
    for i in url:
        video_comments.append(i.text)

print(len(video_comments))
# Out:
# 615

# %%
print(video_comments)
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', 'Click here to subscribe to Sony LIV Channel:    / sonyliv  \n \nClick here to watch all highlights: https://bit.ly/3OVl9LM', '', '', '', 'Livingstone and the ball hitting his nuts , the never ending love story ', 'Living stone on fire he played great innings️\n87 runs on 47 balls', '7:56 why always Livingstone ', 'What a comeback by team Eng after losing the first T20. Livingstone you beauty.  Mighty hitting. ', "8:32 Bethell Like He almost Ben Stokes \n\nEdit:- Got so many likes for the first time\nThank you guy's ️", 'Bahut time ke baad england ki team england team jese kheli \nLivingstone is baar ipl me acha karega', 'Jake, Frazer and McGurk all played well. Australia has 3 young talent on their hands ', 'Hats of to F-McGurk for his absolute innings ', 'Bethell is the future of England cricket ', 'Aud v Eng, full crowd, nothing like it, quality series ', 'What A All-Round Performance By Livingstone On His 50th T20I Match \n\nWell Playe
# ...

# %%
comment_post =[]
start=0
end=2

for page in range(start,end):
    url = driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-view-model"]')
    for i in url:
        comment_post.append(i.text)

print(len(comment_post))
# Out:
# 480

# %%
comment_post =[]
start=0
end=2

for page in range(start,end):
    url = driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-view-model"]')
    for i in url:
        comment_post.append(i.text)

print(comment_post)
# Out:
# ['', '', '3 days ago', '', '', '3 days ago (edited)', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago (edited)', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago (edited)', '', '', '3 days ago (edited)', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '2 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago (edited)', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago (edited)', '', '', '3 days ago', '', '', '3 days ago', '@AnivlogS0920', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', '', '3 days ago', '', ''
# ...
